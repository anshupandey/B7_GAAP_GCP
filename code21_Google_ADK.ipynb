# %% [markdown]
# # Working with Google ADK

# %%
import os
os.makedirs("GoogleADK",exist_ok=True)

# %% [markdown]
# 1. Create an environemtn for ADK
#
#
#     python3 -m venv adkenv
#     source adkenv/bin/activate
#
# 2. install packages
#
#
#     pip install langchain langchain_community google-adk google-genai  pyowm wikipedia pypdf pymupdf --quiet
#     pip install pillow a2a-sdk selenium pypdf2 pypdf uvicorn uv --quiet

# %% [markdown]
# Command to runthe app
#
# navigate to master folder,
#
#
#         adk web

# %%
import os
os.environ['PATH']
# Out:
# '/home/zadmin/Desktop/test/GAAI-B5-GCP/genai/bin:/home/zadmin/Desktop/test/genai/bin:/home/zadmin/genai/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin'

# %%
import sys
sys.path
# Out:
# ['/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/home/zadmin/Desktop/test/GAAI-B5-GCP/genai/lib/python3.11/site-packages']

# %%
import requests
uri = "http://localhost:10000/.well-known/agent.json"
response = requests.get(uri)
response.status_code
# Out:
# 200

# %%
import json
json.loads(response.content.decode())
# Out:
# {'capabilities': {'pushNotifications': True, 'streaming': True},
#  'defaultInputModes': ['text', 'text/plain'],
#  'defaultOutputModes': ['text', 'text/plain'],
#  'description': 'Helps with exchange rates for currencies',
#  'name': 'Currency Agent',
#  'preferredTransport': 'JSONRPC',
#  'protocolVersion': '0.3.0',
#  'skills': [{'description': 'Helps with exchange values between various currencies',
#    'examples': ['What is exchange rate between USD and GBP?'],
#    'id': 'convert_currency',
#    'name': 'Currency Exchange Rates Tool',
#    'tags': ['currency conversion', 'currency exchange']}],
#  'url': 'http://localhost:10000/',
#  'version': '1.0.0'}

# %%
import requests
uri = "http://localhost:8001/.well-known/agent.json"
response = requests.get(uri)
response.status_code
# Out:
# 200

# %%
import json
json.loads(response.content.decode())
# Out:
# {'capabilities': {},
#  'defaultInputModes': ['text/plain'],
#  'defaultOutputModes': ['text/plain'],
#  'description': 'Assitant Agent',
#  'name': 'TredenceAgent',
#  'preferredTransport': 'JSONRPC',
#  'protocolVersion': '0.3.0',
#  'skills': [{'description': 'Assitant Agent I am an expert assistant to human users who can provide correct information, based on internet search results to the users.',
#    'id': 'TredenceAgent',
#    'name': 'model',
#    'tags': ['llm']},
#   {'description': ' this funciton can be used to get current weather information',
#    'id': 'TredenceAgent-get_current_weather',
#    'name': 'get_current_weather',
#    'tags': ['llm', 'tools']},
#   {'description': '',
#    'id': 'TredenceAgent-get_wikipedia_summary',
#    'name': 'get_wikipedia_summary',
#    'tags': ['llm', 'tools']}],
#  'supportsAuthenticatedExtendedCard': False,
#  'url': 'http://localhost:8001',
#  'version': '0.0.1'}

# %%
import httpx
response = httpx.get(
            f'https://api.frankfurter.app/{currency_date}',
            params={'from': 'USD', 'to': 'GBP'},
        )

# %%
respponse.
