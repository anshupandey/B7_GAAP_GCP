# %% [markdown]
# # 5 Levels Of Text Splitting
#
# In this tutorial we are reviewing the 5 Levels Of Text Splitting. This is an unofficial list put together for fun and educational purposes.
#
# Ever try to put a long piece of text into ChatGPT but it tells you it’s too long? Or you're trying to give your application better long term memory, but it’s still just not quite working.
#
# One of the most effective strategies to improve performance of your language model applications is to split your large data into smaller pieces. This is call splitting or chunking (we'll use these terms interchangeably). In the world of multi-modal, splitting also applies to images.
#
# We are going to cover a lot, but if you make it to the end, I guarantee you’ll have a solid grasp on chunking theory, strategies, and resources to learn more.
#
# **Levels Of Text Splitting**
# * **Level 1: [Character Splitting](#CharacterSplitting)** - Simple static character chunks of data
# * **Level 2: [Recursive Character Text Splitting](#RecursiveCharacterSplitting)** - Recursive chunking based on a list of separators
# * **Level 3: [Document Specific Splitting](#DocumentSpecific)** - Various chunking methods for different document types (PDF, Python, Markdown)
# * **Level 4: [Semantic Splitting](#SemanticChunking)** - Embedding walk based chunking
# * **Level 5: [Agentic Splitting](#AgenticChunking)** - Experimental method of splitting text with an agent-like system. Good for if you believe that token cost will trend to $0.00
# * **\*Bonus Level:\*** **[Alternative Representation Chunking + Indexing](#BonusLevel)** - Derivative representations of your raw text that will aid in retrieval and indexing
#
# **Notebook resources:**
# * [Video Overview]() - Walkthrough of this code with commentary
# * [ChunkViz.com](https://www.chunkviz.com/) - Visual representation of chunk splitting methods
# * [RAGAS](https://github.com/explodinggradients/ragas) - Retrieval evaluation framework
#
# This tutorial was created by [Greg Kamradt](https://twitter.com/GregKamradt). MIT license, attribution is always welcome.
#
# This tutorial will use code from LangChain (`pip install langchain`) & Llama Index (`pip install llama-index`)
#
# **Evaluations**
#
# It's important to test your chunking strategies in retrieval evals. It doesn't matter how you chunk if the performance of your application isn't great.
#
# Eval Frameworks:
#
# * [LangChain Evals](https://python.langchain.com/docs/guides/evaluation/)
# * [Llama Index Evals](https://docs.llamaindex.ai/en/stable/module_guides/evaluating/root.html)
# * [RAGAS Evals](https://github.com/explodinggradients/ragas)
#
# I'm not going to demo evals for each method because success is domain specific. The arbitrary eval that I pick may not be suitable for your data. If anyone is interested in collaborating on a rigorous evaluation of different chunking strategies, please reach out (contact@dataindependent.com).
#
# If you only walk away from this tutorial with one thing have it be the **The Chunking Commandment**
#
# **The Chunking Commandment:** Your goal is not to chunk for chunking sake, our goal is to get our data in a format where it can be retrieved for value later.
#
# ## Level 1: Character Splitting <a id="CharacterSplitting"></a>
# Character splitting is the most basic form of splitting up your text. It is the process of simply dividing your text into N-character sized chunks regardless of their content or form.
#
# This method isn't recommended for any applications - but it's a great starting point for us to understand the basics.
#
# * **Pros:** Easy & Simple
# * **Cons:** Very rigid and doesn't take into account the structure of your text
#
# Concepts to know:
# * **Chunk Size** - The number of characters you would like in your chunks. 50, 100, 100,000, etc.
# * **Chunk Overlap** - The amount you would like your sequential chunks to overlap. This is to try to avoid cutting a single piece of context into multiple pieces. This will create duplicate data across chunks.
#
# First let's get some sample text

# %%
text = "This is the text I would like to chunk up. It is the example text for this exercise"

# %% [markdown]
# Then let's split this text manually

# %%
# Create a list that will hold your chunks
chunks = []

chunk_size = 35 # Characters

# Run through the a range with the length of your text and iterate every chunk_size you want
for i in range(0, len(text), chunk_size):
    chunk = text[i:i + chunk_size]
    chunks.append(chunk)
chunks
# Out:
# ['This is the text I would like to ch',
#  'unk up. It is the example text for ',
#  'this exercise']

# %% [markdown]
# Congratulations! You just split your first text. We have long way to go but you're already making progress. Feel like a language model practitioner yet?
#
# When working with text in the language model world, we don't deal with raw strings. It is more common to work with documents. Documents are objects that hold the text you're concerned with, but also additional metadata which makes filtering and manipulation easier later.
#
# We could convert our list of strings into documents, but I'd rather start from scratch and create the docs.
#
# Let's load up LangChains `CharacterSplitter` to do this for us

# %%
from langchain_text_splitters import CharacterTextSplitter

# %% [markdown]
# Then let's load up this text splitter. I need to specify `chunk overlap` and `separator` or else we'll get funk results. We'll get into those next

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=0, separator='', strip_whitespace=False)

# %% [markdown]
# Then we can actually split our text via `create_documents`. Note: `create_documents` expects a list of texts, so if you just have a string (like we do) you'll need to wrap it in `[]`

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to ch'),
#  Document(metadata={}, page_content='unk up. It is the example text for '),
#  Document(metadata={}, page_content='this exercise')]

# %% [markdown]
# Notice how this time we have the same chunks, but they are in documents. These will play nicely with the rest of the LangChain world. Also notice how the trailing whitespace on the end of the 2nd chunk is missing. This is because LangChain removes it, see [this line](https://github.com/langchain-ai/langchain/blob/f36ef0739dbb548cabdb4453e6819fc3d826414f/libs/langchain/langchain/text_splitter.py#L167) for where they do it. You can avoid this with `strip_whitespace=False`

# %% [markdown]
# **Chunk Overlap & Separators**
#
# **Chunk overlap** will blend together our chunks so that the tail of Chunk #1 will be the same thing and the head of Chunk #2 and so on and so forth.
#
# This time I'll load up my overlap with a value of 4, this means 4 characters of overlap

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=4, separator='')

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to ch'),
#  Document(metadata={}, page_content='o chunk up. It is the example text'),
#  Document(metadata={}, page_content='ext for this exercise')]

# %% [markdown]
# Notice how we have the same chunks, but now there is overlap between 1 & 2 and 2 & 3. The 'o ch' on the tail of Chunk #1 matches the 'o ch' of the head of Chunk #2.
#
# I wanted a better way to visualize this, so I made [ChunkViz.com](www.chunkviz.com) to help show it. Here's what the same text looks like.
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/ChunkVizCharacter34_4_w_overlap.png?raw=true" alt="image" style="max-width: 800px;">
# </div>
#
# static/ChunkVizCharacterRecursive.png
#
# Check out how we have three colors, with two overlaping sections.
#
# **Separators** are character(s) sequences you would like to split on. Say you wanted to chunk your data at `ch`, you can specify it.

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=0, separator='ch')

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to'),
#  Document(metadata={}, page_content='unk up. It is the example text for this exercise')]

# %% [markdown]
# ## Level 2: Recursive Character Text Splitting
# <a id="RecursiveCharacterSplitting"></a>
# Let's jump a level of complexity.
#
# The problem with Level #1 is that we don't take into account the structure of our document at all. We simply split by a fix number of characters.
#
# The Recursive Character Text Splitter helps with this. With it, we'll specify a series of separatators which will be used to split our docs.
#
# You can see the default separators for LangChain [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L842). Let's take a look at them one by one.
#
# * "\n\n" - Double new line, or most commonly paragraph breaks
# * "\n" - New lines
# * " " - Spaces
# * "" - Characters
#
# I'm not sure why a period (".") isn't included on the list, perhaps it is not universal enough? If you know, let me know.
#
# This is the swiss army knife of splitters and my first choice when mocking up a quick application. If you don't know which splitter to start with, this is a good first bet.
#
# Let's try it out

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# Then let's load up a larger piece of text

# %%
text = """
One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear.

Teachers and coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your competitor's, you don't get half as many customers. You get no customers, and you go out of business.

It's obviously true that the returns for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these, the rich get richer. [1]
"""

# %% [markdown]
# Now let's make our text splitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 65, chunk_overlap=0)

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content="One of the most important things I didn't understand about the"),
#  Document(metadata={}, page_content='world when I was a child is the degree to which the returns for'),
#  Document(metadata={}, page_content='performance are superlinear.'),
#  Document(metadata={}, page_content='Teachers and coaches implicitly told us the returns were linear.'),
#  Document(metadata={}, page_content='"You get out," I heard a thousand times, "what you put in." They'),
#  Document(metadata={}, page_content='meant well, but this is rarely true. If your product is only'),
#  Document(metadata={}, page_content="half as good as your competitor's, you don't get half as many"),
#  Document(metadata={}, page_content='customers. You get no customers, and you go out of business.'),
#  Document(metadata={}, page_content="It's obviously true that the returns for performance are"),
#  Document(metadata={}, page_content='superlinear in business. Some think this is a flaw of'),
#  Document(metadata={}, page_content='capitalism, and that if we changed the rules it would stop being'),
#  Document(metadata={}, page_content='true. But superlinear returns for performance are a feature of'),
#  Document(metadata={}, page_content="the world, not an artifact of rules we've invented. We see the"),
#  Document(metadata={}, page_content='same pattern in fame, power, military victories, knowledge, and'),
#  Document(metadata={}, page_content='even benefit to humanity. In all of these, the rich get richer.'),
#  Document(metadata={}, page_content='[1]')]

# %% [markdown]
# Notice how now there are more chunks that end with a period ".". This is because those likely are the end of a paragraph and the splitter first looks for double new lines (paragraph break).
#
# Once paragraphs are split, then it looks at the chunk size, if a chunk is too big, then it'll split by the next separator. If the chunk is still too big, then it'll move onto the next one and so forth.
#
# For text of this size, let's split on something bigger.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 450, chunk_overlap=0)
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content="One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear."),
#  Document(metadata={}, page_content='Teachers and coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your competitor\'s, you don\'t get half as many customers. You get no customers, and you go out of business.'),
#  Document(metadata={}, page_content="It's obviously true that the returns for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these, the rich get richer. [1]")]

# %% [markdown]
# For this text, 450 splits the paragraphs perfectly. You can even switch the chunk size to 469 and get the same splits. This is because this splitter builds in a bit of cushion and wiggle room to allow your chunks to 'snap' to the nearest separator.
#
# Let's view this visually
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/ChunkVizCharacterRecursive.png?raw=true" alt="image" style="max-width: 800px;">
# </div>
#
# Wow - you already made it to level 2, awesome! We're on a roll. If you like the content, I send updates to email subscribers on projects I'm working on. If you want to get the scoop, sign up [here](https://mail.gregkamradt.com/signup).

# %% [markdown]
# ## Level 3: Document Specific Splitting <a id="DocumentSpecific"></a>
#
# Stepping up our levels ladder, let's start to handle document types other than normal prose in a .txt. What if you have pictures? or a PDF? or code snippets?
#
# Our first two levels wouldn't work great for this so we'll need to find a different tactic.
#
# This level is all about making your chunking strategy fit your different data formats. Let's run through a bunch of examples of this in action
#
# The Markdown, Python, and JS splitters will basically be similar to Recursive Character, but with different separators.
#
# See all of LangChains document splitters [here](https://python.langchain.com/docs/modules/data_connection/document_transformers/text_splitters/code_splitter) and Llama Index ([HTML](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#htmlnodeparser), [JSON](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#jsonnodeparser), [Markdown](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#markdownnodeparser))
#
# ### Markdown
#
# You can see the separators [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L1175).
#
# Separators:
# * `\n#{1,6}` - Split by new lines followed by a header (H1 through H6)
# * ```` ```\n ```` - Code blocks
# * `\n\\*\\*\\*+\n` - Horizontal Lines
# * `\n---+\n` - Horizontal Lines
# * `\n___+\n` - Horizontal Lines
# * `\n\n` Double new lines
# * `\n` - New line
# * `" "` - Spaces
# * `""` - Character

# %%
from langchain_text_splitters import MarkdownTextSplitter

# %%
splitter = MarkdownTextSplitter(chunk_size = 40, chunk_overlap=0)

# %%
markdown_text = """
# Fun in California

## Driving

Try driving on the 1 down to San Diego

### Food

Make sure to eat a burrito while you're there

## Hiking

Go to Yosemite
"""

# %%
splitter.create_documents([markdown_text])
# Out:
# [Document(metadata={}, page_content='# Fun in California\n\n## Driving'),
#  Document(metadata={}, page_content='Try driving on the 1 down to San Diego'),
#  Document(metadata={}, page_content='### Food'),
#  Document(metadata={}, page_content="Make sure to eat a burrito while you're"),
#  Document(metadata={}, page_content='there'),
#  Document(metadata={}, page_content='## Hiking\n\nGo to Yosemite')]

# %% [markdown]
# Notice how the splits gravitate towards markdown sections. However, it's still not perfect. Check out how there is a chunk with just "there" in it. You'll run into this at low-sized chunks.
#
# ### Python
#
# See the python splitters [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L1069)
#
# * `\nclass` - Classes first
# * `\ndef` - Functions next
# * `\n\tdef` - Indented functions
# * `\n\n` - Double New lines
# * `\n` - New Lines
# * `" "` - Spaces
# * `""` - Characters
#
#
# Let's load up our splitter

# %%
from langchain_text_splitters import PythonCodeTextSplitter

# %%
python_text = """
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

for i in range(10):
    print (i)
"""

# %%
python_splitter = PythonCodeTextSplitter(chunk_size=100, chunk_overlap=0)

# %%
python_splitter.create_documents([python_text])
# Out:
# [Document(metadata={}, page_content='class Person:\n  def __init__(self, name, age):\n    self.name = name\n    self.age = age'),
#  Document(metadata={}, page_content='p1 = Person("John", 36)\n\nfor i in range(10):\n    print (i)')]

# %% [markdown]
# Check out how the class stays together in a single document (good), then the rest of the code is in a second document (ok).
#
# I needed to play with the chunk size to get a clean result like that. You'll likely need to do the same for yours which is why using evaluations to determine optimal chunk sizes is crucial.
#
# ### JS
#
# Very similar to python. See the separators [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L983).
#
# Separators:
# * `\nfunction` - Indicates the beginning of a function declaration
# * `\nconst` - Used for declaring constant variables
# * `\nlet` - Used for declaring block-scoped variables
# * `\nvar` - Used for declaring a variable
# * `\nclass` - Indicates the start of a class definition
# * `\nif` - Indicates the beginning of an if statement
# * `\nfor` - Used for for-loops
# * `\nwhile` - Used for while-loops
# * `\nswitch` - Used for switch statements
# * `\ncase` - Used within switch statements
# * `\ndefault` - Also used within switch statements
# * `\n\n` - Indicates a larger separation in text or code
# * `\n` - Separates lines of code or text
# * `" "` - Separates words or tokens in the code
# * `""` - Makes every character a separate element

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

# %%
javascript_text = """
// Function is called, the return value will end up in x
let x = myFunction(4, 3);

function myFunction(a, b) {
// Function returns the product of a and b
  return a * b;
}
"""

# %%
js_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.JS, chunk_size=65, chunk_overlap=0
)

# %%
js_splitter.create_documents([javascript_text])
# Out:
# [Document(metadata={}, page_content='// Function is called, the return value will end up in x'),
#  Document(metadata={}, page_content='let x = myFunction(4, 3);'),
#  Document(metadata={}, page_content='function myFunction(a, b) {'),
#  Document(metadata={}, page_content='// Function returns the product of a and b\n  return a * b;\n}')]

# %% [markdown]
# ### PDFs w/ tables
#
# Ok now things will get a bit spicier.
#
# PDFs are an extremely common data type for language model work. Often they'll contain tables that contain information.
#
# This could be financial data, studies, academic papers, etc.
#
# Trying to split tables by a character based separator isn't reliable. We need to try out a different method. For a deep dive on this I recommend checking out [Lance Martin's](https://twitter.com/RLanceMartin) [tutorial](https://twitter.com/RLanceMartin/status/1721942636364456336) w/ LangChain.
#
# I'll be going through a text based methods. [Mayo](https://twitter.com/mayowaoshin) has also outlined a GPT-4V method which tries to pulls tables via vision rather than text. You can check out [here](https://twitter.com/mayowaoshin/status/1727399231734886633).
#
# A very convenient way to do this is with [Unstructured](https://unstructured.io/), a library dedicated to making your data LLM ready.

# %%
# !python -m pip install pillow_heif opencv-python --quiet
# Out:
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'

# %%
# !python -m pip install -U opencv-python unstructured "unstructured[pdf]"
# Out:
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: opencv-python in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: unstructured in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (0.22.23)
# Requirement already satisfied: numpy>=2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from opencv-python) (2.4.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (3.4.7)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (3.25.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (6.1.0)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (0.65.1)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (2026.4.20)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (3.14.5)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (2026.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (2.33.1)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (3.8.14)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (0.43.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured) (2.1.2)
# Collecting google-cloud-vision<4.0.0,>=3.12.1 (from unstructured[pdf])
#   Downloading google_cloud_vision-3.13.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting pdf2image<2.0.0,>=1.17.0 (from unstructured[pdf])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer-six<20270000,>=20251230 (from unstructured[pdf])
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting pi-heif<2.0.0,>=1.2.0 (from unstructured[pdf])
#   Downloading pi_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pikepdf<11.0.0,>=10.3.0 (from unstructured[pdf])
#   Downloading pikepdf-10.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pypdf<7.0.0,>=6.6.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured[pdf]) (6.10.0)
# Collecting unstructured-inference<2.0.0,>=1.6.6 (from unstructured[pdf])
#   Downloading unstructured_inference-1.6.10-py3-none-any.whl.metadata (5.6 kB)
# Collecting unstructured-pytesseract<1.0.0,>=0.3.15 (from unstructured[pdf])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.8.3)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (2.30.3)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (2.49.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.80.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.27.2)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (5.29.6)
# Requirement already satisfied: six>=1.9 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.5.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.47.0)
# Requirement already satisfied: pillow in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pdf2image<2.0.0,>=1.17.0->unstructured[pdf]) (12.2.0)
# Requirement already satisfied: cryptography>=36.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pdfminer-six<20270000,>=20251230->unstructured[pdf]) (46.0.7)
# Collecting Deprecated (from pikepdf<11.0.0,>=10.3.0->unstructured[pdf])
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pikepdf<11.0.0,>=10.3.0->unstructured[pdf]) (24.2)
# Requirement already satisfied: click in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.1.8)
# Requirement already satisfied: olefile in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2026.2.25)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.23.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.12.5)
# Requirement already satisfied: jinja2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (82.0.1)
# Requirement already satisfied: aiofiles>=25.1.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdfium2>=5.6.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.7.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Collecting accelerate>=1.12.0 (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.10.2)
# Requirement already satisfied: matplotlib>=3.10.8 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (3.10.8)
# Collecting onnx>=1.20.1 (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: onnxruntime>=1.25.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.25.1)
# Requirement already satisfied: pandas>=1.5.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (2.3.3)
# Requirement already satisfied: scipy>=1.17.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.17.1)
# Collecting timm>=1.0.24 (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading timm-1.0.26-py3-none-any.whl.metadata (39 kB)
# Collecting torch>=2.10.0 (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers>=4.25.1 (from unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading transformers-5.7.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: pyyaml in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from accelerate>=1.12.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (6.0.3)
# Collecting safetensors>=0.4.3 (from accelerate>=1.12.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=2.0.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer-six<20270000,>=20251230->unstructured[pdf]) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (0.4.2)
# Requirement already satisfied: h11>=0.16 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.13.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from huggingface-hub>=0.22.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from huggingface-hub>=0.22.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (2.9.0.post0)
# Collecting ml_dtypes>=0.5.0 (from onnx>=1.20.1->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: flatbuffers in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from onnxruntime>=1.25.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (25.12.19)
# Requirement already satisfied: pytz>=2020.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pandas>=1.5.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pandas>=1.5.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Collecting torchvision (from timm>=1.0.24->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading torchvision-0.26.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting setuptools (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (3.6.1)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.0 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.28.9 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.6.0 (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cublas==13.1.0.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf]) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (7.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: pycparser in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six<20270000,>=20251230->unstructured[pdf]) (3.0)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings<14,>=13.0.3->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading cuda_pathfinder-1.5.4-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (0.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.20.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.6->unstructured[pdf])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: mdurl~=0.1 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)
# Downloading google_cloud_vision-3.13.0-py3-none-any.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 4.7 MB/s eta 0:00:00m eta 0:00:010:01
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 29.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pi_heif-1.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.4 MB/s eta 0:00:00
# Downloading pikepdf-10.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 65.6 MB/s eta 0:00:000m eta 0:00:01
# Downloading unstructured_inference-1.6.10-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.2 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 26.4 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 65.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading timm-1.0.26-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 51.7 MB/s eta 0:00:00m eta 0:00:01
# Downloading torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (530.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 3.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 3.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 5.7 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 34.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 5.5 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 3.4 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 98.4 MB/s eta 0:00:000m eta 0:00:01:01
# Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 22.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 88.7 MB/s eta 0:00:00
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:000m eta 0:00:01
# Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 26.2 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 7.2 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 13.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 48.8 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 16.5 MB/s eta 0:00:00
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.8 MB/s eta 0:00:00
# Downloading transformers-5.7.0-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 56.2 MB/s eta 0:00:00m eta 0:00:0136m0:00:01m
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 62.8 MB/s eta 0:00:000m eta 0:00:01:01
# Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 77.7 MB/s eta 0:00:0031m108.0 MB/s eta 0:00:01
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.2/507.2 kB 39.3 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 96.6 MB/s eta 0:00:0031m165.9 MB/s eta 0:00:01
# Downloading torchvision-0.26.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 95.3 MB/s eta 0:00:000m eta 0:00:010:01
# Downloading cuda_pathfinder-1.5.4-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 5.0 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 39.7 MB/s eta 0:00:00
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# Installing collected packages: nvidia-cusparselt-cu13, mpmath, cuda-toolkit, unstructured-pytesseract, triton, sympy, setuptools, safetensors, pi-heif, pdf2image, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, ml_dtypes, Deprecated, cuda-pathfinder, pikepdf, onnx, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, cuda-bindings, pdfminer-six, nvidia-cusolver, torch, transformers, torchvision, google-cloud-vision, accelerate, timm, unstructured-inference
#   Attempting uninstall: setuptools
#     WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
#     WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
#     WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# Successfully installed Deprecated-1.3.1 accelerate-1.13.0 cuda-bindings-13.2.0 cuda-pathfinder-1.5.4 cuda-toolkit-13.0.2 google-cloud-vision-3.13.0 ml_dtypes-0.5.4 mpmath-1.3.0 nvidia-cublas-13.1.0.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.0 nvidia-nccl-cu13-2.28.9 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 onnx-1.21.0 pdf2image-1.17.0 pdfminer-six-20260107 pi-heif-1.3.0 pikepdf-10.5.1 safetensors-0.7.0 setuptools-81.0.0 sympy-1.14.0 timm-1.0.26 torch-2.11.0 torchvision-0.26.0 transformers-5.7.0 triton-3.6.0 unstructured-inference-1.6.10 unstructured-pytesseract-0.3.15

# %%
# install tesseract
# sudo apt install -y tesseract-ocr

# %%
import os
from unstructured.partition.pdf import partition_pdf
from unstructured.staging.base import elements_to_json

# %% [markdown]
# Let's load up our PDF and then parition it. This is a PDF from a [Salesforce earning report](https://investor.salesforce.com/financials/default.aspx).

# %%
filename = "../datasets/SalesforceFinancial.pdf"

# Extracts the elements from the PDF
elements = partition_pdf(
    filename=filename,

    # Unstructured Helpers
    strategy="hi_res", 
    infer_table_structure=True, 
    model_name="yolox"
)
# Out:
# No languages specified, defaulting to English.
# preprocessor_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/367 [00:00<?, ?it/s]

# %% [markdown]
# Let's look at our elements

# %%
elements
# Out:
# [<unstructured.documents.elements.NarrativeText at 0x751602130dd0>,
#  <unstructured.documents.elements.NarrativeText at 0x751602130c80>,
#  <unstructured.documents.elements.NarrativeText at 0x751602130890>,
#  <unstructured.documents.elements.NarrativeText at 0x751602130650>,
#  <unstructured.documents.elements.NarrativeText at 0x751602130380>,
#  <unstructured.documents.elements.NarrativeText at 0x7516021301d0>,
#  <unstructured.documents.elements.NarrativeText at 0x751602108800>,
#  <unstructured.documents.elements.NarrativeText at 0x7516021083b0>,
#  <unstructured.documents.elements.Text at 0x75160210b2c0>,
#  <unstructured.documents.elements.Text at 0x75160210ad20>,
#  <unstructured.documents.elements.Table at 0x75160210bfe0>,
#  <unstructured.documents.elements.Text at 0x75160210bc20>,
#  <unstructured.documents.elements.Text at 0x75160210a810>,
#  <unstructured.documents.elements.Text at 0x75160210a4b0>,
#  <unstructured.documents.elements.Text at 0x75160210ac90>,
#  <unstructured.documents.elements.NarrativeText at 0x75160210a690>,
#  <unstructured.documents.elements.NarrativeText at 0x75160210a540>]

# %% [markdown]
# These are just unstructured objects, we could look at them all but I want to look at the table it parsed.

# %%
elements[-4].metadata.text_as_html

# %% [markdown]
# That table may look messy, but because it's in HTML format, the LLM is able to parse it much more easily than if it was tab or comma separated. You can copy and paste that html into a [html viewer](https://codebeautify.org/htmlviewer) online to see it reconstructed.
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/SalesforceFinancialTable.png?raw=true" alt="image" style="max-width: 800px;">
# </div>

# %% [markdown]
# Awesome, Unstructured was able to pull out the tables for us. It's not perfect, but the team is upgrading their toolset all the time.
#
# **Important Point:** Later on when we are doing semantic search over our chunks, trying to match on embeddings from the table directly will be difficult. A common practice that developers do is to *summarize* the table after you've extracted it. Then get an embedding of that summary. If the summary embedding matches what you're looking for, then pass the raw table to your LLM.
#
# ### Multi-Modal (text + images)
#
# Next we'll dive into the world of multi-modal text splitting. This is a very active field and best practices are evolving. I'll show you a method that was made popular by [Lance Martin](https://twitter.com/RLanceMartin/status/1713638963255366091) of LangChain. You can check out his source code [here](https://github.com/langchain-ai/langchain/blob/master/cookbook/Semi_structured_and_multi_modal_RAG.ipynb). If you find a method that works better, share it out with the community!

# %%
#!pip3 install "unstructured[all-docs]"
from typing import Any

from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf

# %% [markdown]
# First, let's go get a PDF to work with. This will be from a visual instruction tuning [paper](https://llava-vl.github.io/).
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/VisualInstructionSnapshot.png?raw=true" alt="image" style="max-width: 800px;">
# </div>

# %%
filepath = "../datasets/VisualInstruction.pdf"

# %%
# Get elements
raw_pdf_elements = partition_pdf(
    filename=filepath,
    
    # Using pdf format to find embedded image blocks
    extract_images_in_pdf=True,
    
    # Use layout model (YOLOX) to get bounding boxes (for tables) and find titles
    # Titles are any sub-section of the document
    infer_table_structure=True,
    
    # Post processing to aggregate text once we have the title
    chunking_strategy="by_title",
    # Chunking params to aggregate text blocks
    # Attempt to create a new chunk 3800 chars
    # Attempt to keep chunks > 2000 chars
    # Hard max on chunks
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
    image_output_dir_path="datasets/pdfImages/",
)

# %% [markdown]
# If you head over to `static/pdfImages/` and check out the images that were parsed.
#
# But the images don't do anything sitting in a folder, we need to do something with them! Though a bit outside the scope of chunking, let's talk about how to work with these.
#
# The common tactics will either use a multi-modal model to generate summaries of the images or use the image itself for your task. Others get embeddings of images (like [CLIP](https://openai.com/research/clip)).
#
# Let's generate summaries so you'll be inspired to take this to the next step. We'll use GPT-4V. Check out other models [here](https://platform.openai.com/docs/model).

# %%
from langchain_core.messages import HumanMessage
import os
from dotenv import load_dotenv
from PIL import Image
import base64
import io

load_dotenv()
# Out:
# True

# %% [markdown]
# We'll be using gpt-4-vision today

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model('gemini-2.5-flash', model_provider="google_genai")

# %% [markdown]
# I'm creating quick helper function to convert the image from file to base64 so we can pass it to GPT-4V

# %%
# Function to convert image to base64
def image_to_base64(image_path):
    with Image.open(image_path) as image:
        buffered = io.BytesIO()
        image.save(buffered, format=image.format)
        img_str = base64.b64encode(buffered.getvalue())
        return img_str.decode('utf-8')

image_str = image_to_base64("figures/figure-15-6.jpg")

# %% [markdown]
# Then we can go ahead and pass our image to the LLM

# %%
from langchain.chat_models import init_chat_model
chat = init_chat_model('gemini-2.5-flash', model_provider="google_genai")


msg = chat.invoke(
    [
        HumanMessage(
            content=[
                {"type": "text", "text" : "Please give a summary of the image provided. Be descriptive"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_str}"
                    },
                },
            ]
        )
    ]
)

# %% [markdown]
# Then the summary returned is what we will put into our vectordata base. Then when it comes time to do our retrieval process, we'll use these embeddings for semantic search.

# %%
msg.content
# Out:
# 'This image is a humorous meme that combines text with a photograph to create an ironic effect.\n\nAt the top of the image, white text on a black background reads: "Sometimes I just look at pictures of the earth from space and I marvel at how beautiful it all is."\n\nBelow this text is a close-up photograph of numerous golden-brown, irregularly shaped pieces of breaded food, strongly resembling chicken nuggets or fried chicken pieces. These food items are meticulously arranged on a dark, well-used metal baking sheet to form a recognizable, albeit somewhat crude, map of the world\'s continents.\n\nSpecific landmasses can be identified:\n*   **North America** is represented by a cluster of pieces in the upper left.\n*   **South America** is a distinct, elongated piece directly below North America.\n*   **Africa** is formed by a large, prominent piece to the right of South America.\n*   **Eurasia** is a larger, more spread-out collection of pieces in the upper right.\n*   **Australia** appears as a smaller, isolated piece in the lower right.\n*   **Antarctica** is a long, somewhat abstract piece at the bottom left.\n\nThe food pieces have a textured, crispy appearance, and the dark baking sheet shows some scattered crumbs and darker, possibly burnt residue, suggesting it has been used for cooking. The lighting is warm, highlighting the golden color of the "continents."\n\nThe humor of the image comes from the juxtaposition of the text, which expresses a profound appreciation for the Earth\'s beauty, with the literal and somewhat comical representation of the world made from fried food on a mundane baking sheet.'

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/pdfImages/figure-15-6.jpg?raw=true" alt="image" style="max-width: 800px;"><br>
#     <span><i>static/pdfImages/figure-15-6.jpg</i></span>
# </div>
#
# Hm, that seems about right!
#
# There are a ton of ways to go about this (check out the bonus section for more) so don't take my word for it - try 'em.

# %% [markdown]
# ## Level 4: Semantic Chunking <a id="SemanticChunking"></a>
# Isn't it weird that we have a global constant for chunk size? Isn't it even weirder that our normal chunking mechanisms don't take into account the actual content?
#
# I'm not the only one who thinks so
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/SemanticChunkingTweet.png?raw=true" style="max-width:50%; height:auto;"><br>
#     <span><i><a href="https://twitter.com/thesephist/status/1724159343237456248?s=46">Source</a></i></span>
# </div>
#
# There has to be a better way - let's explore and find out.
#
# Embeddings represent the semantic meaning of a string. They don't do much on their own, but when compared to embeddings of other texts you can start to infer the relationship between chunks. I want to lean into this property and explore using embeddings to find clusters of semantically similar texts.
#
# The hypothesis is that semantically similar chunks should be held together.
#
# I tried a few methods:
# 1) **Heirarchical clustering with positional reward** - I wanted to see how heirarchical clustering of sentence embeddings would do. But because I chose to split on sentences, there was an issue with small short sentences after a long one. You know? (like this last sentenence). They could change the meaning of a chunk, so I added a positional reward and clusters were more likely to form if they were sentences next to each other. This ended up being ok, but tuning the parameters was slow and unoptimal.
# 2) **Find break points between sequential sentences** - Next up I tried a walk method. I started at the first sentence, got the embedding, then compared it to sentence #2, then compared #2 and #3 and so on. I was looking for "break points" where embedding distance was large. If it was above a threshold, then I considered it the start of a new semantic section. I originally tried taking embeddings of every sentence, but this turned out to be too noisy. So I ended up taking groups of 3 sentences (a window), then got an embedding, then dropped the first sentence, and added the next one. This worked out a bit better.
#
# I'll show method #2 here - It's not perfect by any means, but it's a good starting point for an exploration and I'd love to hear about how you think it could be improved.
#
# First, let's load up our essay that we'll run through. I'm just doing a single essay here to keep the tokens down.
#
# We'll be using Paul Graham's [MIT essay](https://paulgraham.com/mit.html)

# %%
with open('../datasets/mit.txt') as file:
    essay = file.read()

# %% [markdown]
# Then I want to split the entire essay into 1-sentence chunks. I'm going to split on "." "?" and "!". There are better ways to do this but this is quick and easy for now.

# %%
import re

# Splitting the essay on '.', '?', and '!'
single_sentences_list = re.split(r'(?<=[.?!])\s+', essay)
print (f"{len(single_sentences_list)} senteneces were found")
# Out:
# 317 senteneces were found

# %% [markdown]
# But a list of sentences can be tough to add more data too. I'm going to turn this into a list of dictionaries (`List[dict]`), of which, the sentences will be a key-value. Then we can start to add more data to each sentence.

# %%
sentences = [{'sentence': x, 'index' : i} for i, x in enumerate(single_sentences_list)]
sentences[:3]
# Out:
# [{'sentence': '\n\nWant to start a startup?', 'index': 0},
#  {'sentence': 'Get funded by\nY Combinator.', 'index': 1},
#  {'sentence': 'October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.',
#   'index': 2}]

# %% [markdown]
# Great, now that we have our sentences, I want to combine the sentence before and after so that we reduce noise and capture more of the relationships between sequential sentences.
#
# Let's create a function so we can use it again. The `buffer_size` is configurable so you can select how big of a window you want. Keep this number in mind for the later steps. I'll just use `buffer_size=1` for now.

# %%
def combine_sentences(sentences, buffer_size=1):
    # Go through each sentence dict
    for i in range(len(sentences)):

        # Create a string that will hold the sentences which are joined
        combined_sentence = ''

        # Add sentences before the current one, based on the buffer size.
        for j in range(i - buffer_size, i):
            # Check if the index j is not negative (to avoid index out of range like on the first one)
            if j >= 0:
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += sentences[j]['sentence'] + ' '

        # Add the current sentence
        combined_sentence += sentences[i]['sentence']

        # Add sentences after the current one, based on the buffer size
        for j in range(i + 1, i + 1 + buffer_size):
            # Check if the index j is within the range of the sentences list
            if j < len(sentences):
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += ' ' + sentences[j]['sentence']

        # Then add the whole thing to your dict
        # Store the combined sentence in the current sentence dict
        sentences[i]['combined_sentence'] = combined_sentence

    return sentences

sentences = combine_sentences(sentences)

# %%
sentences[:3]
# Out:
# [{'sentence': '\n\nWant to start a startup?',
#   'index': 0,
#   'combined_sentence': '\n\nWant to start a startup? Get funded by\nY Combinator.'},
#  {'sentence': 'Get funded by\nY Combinator.',
#   'index': 1,
#   'combined_sentence': '\n\nWant to start a startup? Get funded by\nY Combinator. October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.'},
#  {'sentence': 'October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.',
#   'index': 2,
#   'combined_sentence': 'Get funded by\nY Combinator. October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school. I think there will increasingly be a third option:\nto start your own startup.'}]

# %% [markdown]
# Check out how the 2nd sentence (index #1) has the first sentence and 3rd sentence in its `combined_sentence` key now.
#
# Now I want to get embeddings for the combined sentences, so we can get the distances between the groups of 3 and find breakpoints. I'll use OpenAI's embeddings for this.

# %%
embedding_model_name = "models/gemini-embedding-001"

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
embeddings = GoogleGenerativeAIEmbeddings(model=embedding_model_name)

# %% [markdown]
# Now let's go get our embeddings. We'll do this in batch to make it quicker.

# %%
embeddings = embeddings.embed_documents([x['combined_sentence'] for x in sentences])

# %% [markdown]
# Now we have a list of embeddings, but we need to add them to our list of dicts

# %%
for i, sentence in enumerate(sentences):
    sentence['combined_sentence_embedding'] = embeddings[i]

# %% [markdown]
# Great, now we're getting to the cool part, let's check out the cosine distances between sequential embedding pairs to see where the break points are. We'll add 'distance_to_next' as another key

# %%
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_distances(sentences):
    distances = []
    for i in range(len(sentences) - 1):
        embedding_current = sentences[i]['combined_sentence_embedding']
        embedding_next = sentences[i + 1]['combined_sentence_embedding']
        
        # Calculate cosine similarity
        similarity = cosine_similarity([embedding_current], [embedding_next])[0][0]
        
        # Convert to cosine distance
        distance = 1 - similarity

        # Append cosine distance to the list
        distances.append(distance)

        # Store distance in the dictionary
        sentences[i]['distance_to_next'] = distance

    # Optionally handle the last sentence
    # sentences[-1]['distance_to_next'] = None  # or a default value

    return distances, sentences

# %% [markdown]
# Great, now let's pull out the distances from our sentences and then add them as well

# %%
distances, sentences = calculate_cosine_distances(sentences)

# %% [markdown]
# Let's take a look at what our distances array looks like.

# %%
distances[:3]
# Out:
# [np.float64(0.11125043517420019),
#  np.float64(0.021543991866918244),
#  np.float64(0.06198295535693721)]

# %% [markdown]
# Hm, yep, just a bunch of numbers that aren't fun to look at. Let's plot them.

# %%
import matplotlib.pyplot as plt

plt.plot(distances);

# %% [markdown]
# Hm, cool! It's interesting to see sections where distances are smaller and then areas of larger distances. What stands out to me most is the outliers which are spread out.
#
# There are many ways to chunk up the essay based off these distances, but I'm going to consider any distance above the 95th percentile of distances as a break point. This is the only parameter we'll need to config.
#
# I'm going to build in the final viz, check out the video for an iterative build and an overview.

# %% [markdown]
# Let's look at the chunks that came out

# %%
import numpy as np

plt.plot(distances);

y_upper_bound = .2
plt.ylim(0, y_upper_bound)
plt.xlim(0, len(distances))

# We need to get the distance threshold that we'll consider an outlier
# We'll use numpy .percentile() for this
breakpoint_percentile_threshold = 95
breakpoint_distance_threshold = np.percentile(distances, breakpoint_percentile_threshold) # If you want more chunks, lower the percentile cutoff
plt.axhline(y=breakpoint_distance_threshold, color='r', linestyle='-');

# Then we'll see how many distances are actually above this one
num_distances_above_theshold = len([x for x in distances if x > breakpoint_distance_threshold]) # The amount of distances above your threshold
plt.text(x=(len(distances)*.01), y=y_upper_bound/50, s=f"{num_distances_above_theshold + 1} Chunks");

# Then we'll get the index of the distances that are above the threshold. This will tell us where we should split our text
indices_above_thresh = [i for i, x in enumerate(distances) if x > breakpoint_distance_threshold] # The indices of those breakpoints on your list

# Start of the shading and text
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i, breakpoint_index in enumerate(indices_above_thresh):
    start_index = 0 if i == 0 else indices_above_thresh[i - 1]
    end_index = breakpoint_index if i < len(indices_above_thresh) - 1 else len(distances)

    plt.axvspan(start_index, end_index, facecolor=colors[i % len(colors)], alpha=0.25)
    plt.text(x=np.average([start_index, end_index]),
             y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
             s=f"Chunk #{i}", horizontalalignment='center',
             rotation='vertical')

# # Additional step to shade from the last breakpoint to the end of the dataset
if indices_above_thresh:
    last_breakpoint = indices_above_thresh[-1]
    if last_breakpoint < len(distances):
        plt.axvspan(last_breakpoint, len(distances), facecolor=colors[len(indices_above_thresh) % len(colors)], alpha=0.25)
        plt.text(x=np.average([last_breakpoint, len(distances)]),
                 y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
                 s=f"Chunk #{i+1}",
                 rotation='vertical')

plt.title("PG Essay Chunks Based On Embedding Breakpoints")
plt.xlabel("Index of sentences in essay (Sentence Position)")
plt.ylabel("Cosine distance between sequential sentences")
plt.show()

# %% [markdown]
# Well now that we've succefully distracted ourselves with a visualization, now we need to combine the sentences into chunks.
#
# Because we have our breakpoints [23, 40, 51...] I want to make the first chunk 0-22, since the distance jumped on sentence 23.

# %%
# Initialize the start index
start_index = 0

# Create a list to hold the grouped sentences
chunks = []

# Iterate through the breakpoints to slice the sentences
for index in indices_above_thresh:
    # The end index is the current breakpoint
    end_index = index

    # Slice the sentence_dicts from the current start index to the end index
    group = sentences[start_index:end_index + 1]
    combined_text = ' '.join([d['sentence'] for d in group])
    chunks.append(combined_text)
    
    # Update the start index for the next group
    start_index = index + 1

# The last group, if any sentences remain
if start_index < len(sentences):
    combined_text = ' '.join([d['sentence'] for d in sentences[start_index:]])
    chunks.append(combined_text)

# grouped_sentences now contains the chunked sentences

# %% [markdown]
# Great now let's manually inspect a few to make sure they look ok.

# %%
for i, chunk in enumerate(chunks[:2]):
    buffer = 200
    
    print (f"Chunk #{i}")
    print (chunk[:buffer].strip())
    print ("...")
    print (chunk[-buffer:].strip())
    print ("\n")
# Out:
# Chunk #0
# Want to start a startup? Get funded by
# Y Combinator. October 2006(This essay is derived from a talk at MIT.)
# Till recently graduating seniors had two choices: get a job or go
# to grad school. I think
# ...
# e tell people not to? For the same reason that the probably
# apocryphal violinist, whenever he was asked to judge someone's
# playing, would always say they didn't have enough talent to make
# it as a pro.
#
#
# Chunk #1
# Succeeding as a musician takes determination as well
# as talent, so this answer works out to be the right advice for
# everyone. The ones who are uncertain believe it and give up, and
# the ones who are su
# ...
# on who we're most excited to see
# applications from, I'd say it's probably the mid-twenties. Why? What advantages does someone in their mid-twenties have over someone
# who's 21? And why isn't it older?

# %% [markdown]
# I want to re-emphasize that this is an exploration of a method that is far from usable yet. This method should be tested with RAG eval to ensure that it works for your use case.
#
# I didn't worry about chunk size or overlap with this method, but you could recursively split large chunks if you needed to.
#
# How should it be improved? Let me [know](https://twitter.com/GregKamradt)! See me tease this [here](https://twitter.com/GregKamradt/status/1737921395974430953).

# %% [markdown]
# ## Level 5: Agentic Chunking <a id="AgenticChunking"></a>
# Taking level 4 even further - can we instruct an LLM to do this task like a human would?
#
# How does a human even go about chunking in the first place?
#
# Well...let me think, how would I go about chunking a document into its discrete parts such that the results were semantically similar?
#
# 1. I would get myself a scratch piece of paper or notepad
# 2. I'd start at the top of the essay and assume the first part will be a chunk (since we don't have any yet)
# 3. Then I would keep going down the essay and evaluate if a new sentence or piece of the essay should be a part of the first chunk, if not, then create a new one
# 4. Then keep doing that all the way down the essay until we got to the end.
#
# Woah! Wait a minute - this is pseudo code for something we can try out. See me tease this [here](https://twitter.com/GregKamradt/status/1738276097471754735).
#
# I debated whether or not to hold myself to the strict standard of using the *raw text* from a document, or use a derived form. The former felt like I was being too harsh, so I decided to explore using [propositions](https://twitter.com/LangChainAI/status/1735708004618764470). This is a cool concept ([research paper](https://arxiv.org/pdf/2312.06648.pdf)) that extracts stand alone statements from a raw piece of text.
#
# Example: `Greg went to the park. He likes walking` > `['Greg went to the park.', 'Greg likes walking']`
#
# Let's do it:

# %%
# !pip install langchainhub --quiet
# Out:
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: langchainhub in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (0.1.21)
# Requirement already satisfied: packaging<25,>=23.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from langchainhub) (24.2)
# Requirement already satisfied: requests<3,>=2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from langchainhub) (2.33.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from langchainhub) (2.33.0.20260408)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3,>=2->langchainhub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3,>=2->langchainhub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3,>=2->langchainhub) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages (from requests<3,>=2->langchainhub) (2026.2.25)
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/pydantic-2.13.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/openai-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/zadmin/Desktop/B7_GAAP_GCP/genai/lib/python3.12/site-packages/langgraph-1.1.6.dist-info due to invalid metadata entry 'name'

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda
from typing import Optional, List
from langchain_classic import hub

# %% [markdown]
# Pulling out propositions is done via a well-crafted prompt. I'm going to pull it from [LangHub](https://smith.langchain.com/hub?organizationId=50995362-9ea0-4378-ad97-b4edae2f9f22), LangChain's home for prompts.
#
# You can view the proposition prompt [here](https://smith.langchain.com/hub/wfh/proposal-indexing?organizationId=50995362-9ea0-4378-ad97-b4edae2f9f22).
#
# I'll use gpt-4 as the LLM because we aren't messing around. I care more about performance than I do speed or cost.

# %%
obj = hub.pull("wfh/proposal-indexing")

from langchain.chat_models import init_chat_model
llm = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# %% [markdown]
# Then I'll make a runnable w/ langchain, this'll be a short way to combine the prompt and llm

# %%
# Pydantic data class
from pydantic import BaseModel

class Sentences(BaseModel):
    sentences: List[str]
    

llm_pydantic = llm.with_structured_output(Sentences)
runnable = obj | llm_pydantic

# %% [markdown]
# Then wrap it together in a function that'll return a list of propositions to us

# %%
def get_propositions(text):
    
    propositions = runnable.invoke({
    	"input": text
    }).sentences
    return propositions

# %% [markdown]
# Go get your text of choice.

# %%
with open('../datasets/superlinear.txt') as file:
    essay = file.read()

# %% [markdown]
# Then you need to decide what you send to your proposal maker. The prompt has an example that is about 1K characters long. So I would experiment with what works for you. This isn't another chunking decision, just pick something reasonable and try it out.
#
# I'm using paragraphs

# %%
paragraphs = essay.split("\n\n")

# %% [markdown]
# Let's see how many we have

# %%
len(paragraphs)
# Out:
# 53

# %% [markdown]
# That's too many for a demo, I'll do just the first couple to show it off.

# %%
essay_propositions = []

for i, para in enumerate(paragraphs[:5]):
    propositions = get_propositions(para)
    
    essay_propositions.extend(propositions)
    print (f"Done with {i}")
# Out:
# Done with 0
# Done with 1
# Done with 2
# Done with 3
# Done with 4

# %% [markdown]
# Let's take a look at what the propositions look like

# %%
print (f"You have {len(essay_propositions)} propositions")
essay_propositions[:10]
# Out:
# You have 25 propositions
# ['The date is October 2023.',
#  'The returns for performance are superlinear.',
#  'I did not understand the degree to which the returns for performance are superlinear when I was a child.',
#  'The degree to which the returns for performance are superlinear was one of the most important things I did not understand about the world.',
#  'Teachers and coaches implicitly told the author that returns were linear.',
#  "The author heard the phrase 'You get out what you put in' a thousand times.",
#  'The teachers and coaches meant well.',
#  "The principle 'You get out what you put in' is rarely true.",
#  "If a product is only half as good as a competitor's product, the product owner does not get half as many customers.",
#  'In such a scenario, a product owner gets no customers.']
